# %% [markdown]
# <a href="https://colab.research.google.com/github/toutenergie/Africa_techup_tour/blob/main/Projet_2024_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/huggingface/transformers -q peft  accelerate bitsandbytes safetensors sentencepiece
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 7.4 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import login

# Ajouter votre jeton
login(token="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")

# %%
# !pip install bitsandbytes

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

model_name = 'heramb96/Mistral-7B-Instruct-v0.1-sharded'

# %%
def load_quantized_model(model_name: str):
    """
    :param model_name: Name or path of the model to be loaded.
    :return: Loaded quantized model.
    """
    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.bfloat16
    )

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        # Remove redundant load_in_4bit argument
        # load_in_4bit=True,
        torch_dtype=torch.bfloat16,
        quantization_config=bnb_config
    )

    return model

# %%
# !pip install bitsandbytes
# !pip install transformers

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

model_name = 'mistralai/Mistral-7B-Instruct-v0.1' # Changed the model name to the main model

def load_quantized_model(model_name: str):
    """
    :param model_name: Name or path of the model to be loaded.
    :return: Loaded quantized model.
    """
    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.bfloat16
    )

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        # Remove redundant load_in_4bit argument
        # load_in_4bit=True,
        torch_dtype=torch.bfloat16,
        quantization_config=bnb_config
    )

    return model

def initialize_tokenizer(model_name: str):
    """
    Initialize the tokenizer with the specified model_name.

    :param model_name: Name or path of the model for tokenizer initialization.
    :return: Initialized tokenizer.
    """
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    tokenizer.bos_token_id = 1  # Set beginning of sentence token id
    return tokenizer


model = load_quantized_model(model_name)

tokenizer = initialize_tokenizer(model_name)

# Define stop token ids
stop_token_ids = [0]

text = "[INST] How AI will replace Engineers [/INST]"

encoded = tokenizer(text, return_tensors="pt", add_special_tokens=False)
model_input = encoded
generated_ids = model.generate(**model_input, max_new_tokens=200, do_sample=True)
decoded = tokenizer.batch_decode(generated_ids)
print(decoded[0])
# Out:
# ...
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.10k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# ...

# %%
# Créer le prompt formaté
prompt_template = """
### Instruction
Réponds précisément à la question posée en utilisant les informations fournies dans le contexte.
Si une question n'setpas dans le contexte donné, indique poliment que l'information n'est pas disponible.

### Question
{question}

### Context
{context}

"""

# Définir les entrées dynamiques
question = ("En tant que citoyen béninois né à l'étranger, quels sont les documents nécessaires pour "
            "obtenir un acte de naissance sécurisé si mes parents sont décédés ?")

context = """
Catégorie: Agence Nationale d’Identification des Personnes.
Titre: Délivrance d'acte de naissance sécurisé (Part 2).
Institution en charge du service: Agence Nationale d’Identification des Personnes.
Institution compétente: Agence Nationale d’Identification des Personnes.
Localisation, heures de service: Patte d’Oie, Cadjèhoun Cotonou, à côté de la station SONACOP de Cadjèhoun
E-Mail : contact@anip.bj
Palais de la Marina 01BP2028 Cotonou-Bénin,
Lundi au Vendredi - Matinée : 08h00mn-12h30mn - Soirée : 12h00mn-17h00mn.
Faire une demande :
❖ Cas des nationaux nés sur le territoire béninois :
   - Copie du récépissé RAVIP ;
   - Copie de l’ancien acte de naissance ;
   - Coût : 1000 F CFA.
❖ Cas des nationaux nés à l'étranger mais de parents béninois :
   - Copie du récépissé RAVIP ;
   - Copie de l’ancien acte de naissance ;
   - Copie du certificat de nationalité ou de l’acte de naissance de l’un des parents béninois ;
   - Coût : 1000 F CFA.
❖ Cas des nationaux nés à l'étranger mais de parents béninois décédés :
   - Copie du récépissé RAVIP ;
   - Copie de l’ancien acte de naissance ;
   - Copie de l’acte de naissance de la mère ou du père décédé ;
   - Copie de l’acte de décès du parent ;
   - Coût : 1000 F CFA.
"""

answer = """
"""

# Remplir le template
filled_prompt = prompt_template.format(
    question=question,
    context=context,
    answer=answer
)

# Encoder le prompt
encoded_input = tokenizer(filled_prompt, return_tensors="pt", add_special_tokens=False)

# Générer une réponse
output_ids = model.generate(**encoded_input, max_new_tokens=200, do_sample=True)

# Décoder la réponse générée
output_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)
print(output_text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# ### Instruction
# Réponds précisément à la question posée en utilisant les informations fournies dans le contexte. Si une question dépasse le contexte donné, indique poliment que l'information n'est pas disponible.
#
# ### Question
# En tant que citoyen béninois né à l'étranger, quels sont les documents nécessaires pour obtenir un acte de naissance sécurisé si mes parents sont décédés ?
#
# ### Context
#
# Catégorie: Agence Nationale d’Identification des Personnes.
# Titre: Délivrance d'acte de naissance sécurisé (Part 2).
# Institution en charge du service: Agence Nationale d’Identification des Personnes.
# Institution compétente: Agence Nationale d’Identification des Personnes.
# Localisation, heures de service: Patte d’Oie, Cadjèhoun Cotonou, à côté de la station SONACOP de Cadjèhoun
# E-Mail : contact@anip.bj
# Palais de la Marina 01BP2028 Cotonou-Bénin,
# ...

# %%
user_question = "Quelles sont les principales dispositions du Code du numérique en République du Bénin concernant la protection des données personnelles ?"
response = generate_response(user_question)
print(response)
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Le Code du numérique est une loi numérique adoptée par la république du Bénin en 2017. L'objectif de ce code est d'encourager l'usage du numérique dans le pays, tout en protégeant les données personnelles des citoyens.
#
# Les principales dispositions concernant la protection des données personnelles sont les suivantes :
#
# 1. La définition des données personnelles : Selon la loi, les données personnelles sont des informations qui permettent d'identifier ou de désigner un citoyen.
# 2. Les obligations des responsables de traitement : Les responsables de traitement des données personnelles sont obligés de prendre toutes les mesures nécessaires pour protéger les données personnelles des risques de destruction, altération, vol

# %%
user_question = "Quels sont les documents nécessaire pour obtenir un passeport Béninois"
response = generate_response(user_question)
print(response)
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Le passeport Béninois est délivré aux citoyens béninois qui ont atteint l’âge de 18 ans. Pour obtenir un passeport, vous devez fournir les documents suivants :
#
# 1. Une photo du candidat (pas de filtre ni de retouche)
# 2. Une copie de l’acte d’état civil (extrait)
# 3. Une copie de l’acte de naissance
# 4. Une copie de l’acte d’identité (nationalité, nom, prénom)
# 5. Une copie de l’acte d’entrée au pays (en cas de résidence étrangère)
# 6. Une copie de la carte de résidence (en cas de résidence au Bénin)
# 7. Une copie de l’acte de cession de national

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "Qwen/Qwen2.5-7B-Instruct"

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto"
)
tokenizer = AutoTokenizer.from_pretrained(model_name)

def generate_response(user_question):
    # Créer le prompt avec une instruction claire
    messages = [
        {"role": "system", "content": "You are Qwen, created by Alibaba Cloud. You are a helpful assistant."},
        {"role": "user", "content": f"Please provide a precise answer to the following question: {user_question} If you don't know the answer, respond with 'I don't know'."}
    ]

    text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

    generated_ids = model.generate(
        **model_inputs,
        max_new_tokens=512
    )

    generated_ids = [
        output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
    ]

    response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

    return response

# Exemple d'utilisation
user_question = "What is the code of digital in Benin?"
response = generate_response(user_question)
print(response)
